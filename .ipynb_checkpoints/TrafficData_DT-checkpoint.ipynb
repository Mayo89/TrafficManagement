# %%
# Load libraries
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn import preprocessing

# %%
col_names = ['Date_Time', 'Time', 'AreaA_Commuters', 'AreaB_Commuters', 'AreaC_Commuters', 'AreaD_Commuters','PeakTraffic', 'PreviousPriority','LargestArea', 'SecondLargestArea', 'Priority']
# load dataset
data = pd.read_csv("Traffic_Data.csv", header=0, names=col_names)
data.head()
# Out:
#          Date_Time        Time  AreaA_Commuters  AreaB_Commuters  \
# 0  2019-09-01 7:00  7:00:00 AM              996             1214
# 1  2019-09-01 7:15  7:15:00 AM             1394              815
# 2  2019-09-01 7:30  7:30:00 AM             1327              820
# 3  2019-09-01 7:45  7:45:00 AM             1325              572
# 4  2019-09-01 8:00  8:00:00 AM              551             1283
#
#    AreaC_Commuters  AreaD_Commuters  PeakTraffic PreviousPriority LargestArea  \
# 0             1185             1017         True                X           X
# 1             1299              601         True                B           A
# 2              564             1466         True                A           D
# 3             1273             1365         True                D           D
# 4             1432             1097         True                A           C
#
#   SecondLargestArea Priority
# 0                 X        B
# 1                 C        A
# 2                 A        D
# 3                 A        A
# 4                 B        C

# %%
#split dataset in features and target variable
feature_cols = ['AreaA_Commuters', 'AreaB_Commuters', 'AreaC_Commuters', 'AreaD_Commuters', 'PeakTraffic', 'PreviousPriority']
X = data[feature_cols] # Features
y = data.Priority # Target variable

# %%
#1. INSTANTIATE
# encode labels with value between 0 and n_classes-1.
le = preprocessing.LabelEncoder()

# 2/3. FIT AND TRANSFORM
# use df.apply() to apply le.fit_transform to all columns
X_2 = X.apply(le.fit_transform)
X_2.head()
# Out:
#    AreaA_Commuters  AreaB_Commuters  AreaC_Commuters  AreaD_Commuters  \
# 0              480              527              515              489
# 1              577              440              546              384
# 2              560              442              351              587
# 3              559              365              541              568
# 4              344              551              577              506
#
#    PeakTraffic  PreviousPriority
# 0            1                 4
# 1            1                 1
# 2            1                 0
# 3            1                 3
# 4            1                 0

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X_2, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# ('Accuracy:', 0.72)

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1','2','3'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('traffic.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-9-d0de8914cb50> in <module>()
#       9                 special_characters=True,feature_names = feature_cols,class_names=['0','1','2','3'])
#      10 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ---> 11 graph.write_png('traffic.png')
#      12 Image(graph.create_png())
#
# c:\python27\lib\site-packages\pydotplus\graphviz.pyc in <lambda>(path, f, prog)
#    1808                 lambda path,
#    1809                 f=frmt,
# -> 1810                 prog=self.prog: self.write(path, format=f, prog=prog)
#    1811             )
#    1812
#
# c:\python27\lib\site-packages\pydotplus\graphviz.pyc in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# c:\python27\lib\site-packages\pydotplus\graphviz.pyc in create(self, prog, format)
#    1958             if self.progs is None:
#    1959                 raise InvocationException(
# -> 1960                     'GraphViz\'s executables not found')
#    1961
#    1962         if prog not in self.progs:
#
# InvocationException: GraphViz's executables not found
